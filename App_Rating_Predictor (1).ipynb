# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\pavan\\Downloads\\googleplaystore.csv")

# %%
df.shape
# Out:
# (10840, 13)

# %%
dfp=df[df['Price']=='Everyone']
dfp
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df.isnull()
# Out:
#          App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0      False     False   False    False  False     False  False  False
# 1      False     False   False    False  False     False  False  False
# 2      False     False   False    False  False     False  False  False
# 3      False     False   False    False  False     False  False  False
# 4      False     False   False    False  False     False  False  False
# ...      ...       ...     ...      ...    ...       ...    ...    ...
# 10835  False     False   False    False  False     False  False  False
# 10836  False     False   False    False  False     False  False  False
# 10837  False     False    True    False  False     False  False  False
# 10838  False     False   False    False  False     False  False  False
# 10839  False     False   False    False  False     False  False  False
#
#        Content Rating  Genres  Last Updated  Current Ver  Android Ver
# ...

# %%
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
df.count()
# Out:
# App               10840
# Category          10840
# Rating             9366
# Reviews           10840
# Size              10840
# Installs          10840
# Type              10839
# Price             10840
# Content Rating    10840
# Genres            10840
# Last Updated      10840
# Current Ver       10832
# Android Ver       10838
# dtype: int64

# %% [markdown]
# # Dropping null values

# %%
df1=df.dropna()

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df1.count()
# Out:
# App               9360
# Category          9360
# Rating            9360
# Reviews           9360
# Size              9360
# Installs          9360
# Type              9360
# Price             9360
# Content Rating    9360
# Genres            9360
# Last Updated      9360
# Current Ver       9360
# Android Ver       9360
# dtype: int64

# %%
import scipy.stats as st
import math as m

# %%
df1.head(50)
# Out:
#                                                   App           Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# 5                          Paper flowers instructions     ART_AND_DESIGN
# 6             Smoke Effect Photo Maker - Smoke Editor     ART_AND_DESIGN
# 7                                    Infinite Painter     ART_AND_DESIGN
# 8                                Garden Coloring Book     ART_AND_DESIGN
# 9                       Kids Paint Free - Drawing Fun     ART_AND_DESIGN
# 10                            Text on Photo - Fonteee     ART_AND_DESIGN
# 11            Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# ...

# %%
df1._get_numeric_data()
# Out:
#        Rating  Reviews
# 0         4.1      159
# 1         3.9      967
# 2         4.7    87510
# 3         4.5   215644
# 4         4.3      967
# ...       ...      ...
# 10833     4.0        7
# 10835     4.5       38
# 10836     5.0        4
# 10838     4.5      114
# 10839     4.5   398307
#
# [9360 rows x 2 columns]

# %%
 df1.select_dtypes('number')
# Out:
#        Rating  Reviews
# 0         4.1      159
# 1         3.9      967
# 2         4.7    87510
# 3         4.5   215644
# 4         4.3      967
# ...       ...      ...
# 10833     4.0        7
# 10835     4.5       38
# 10836     5.0        4
# 10838     4.5      114
# 10839     4.5   398307
#
# [9360 rows x 2 columns]

# %%
df1.dtypes['Size']
# Out:
# dtype('O')

# %%
df2 = df1.infer_objects()
df2.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
def convert(value):
    if value.strip()[-1] == 'M':
        return float(value[0:len(value)-1]) * 1000
    elif value.strip()[1] == 'K':
        return float(value[0:len(value)-1])
    else:
        return None


df2['Size'] = df2['Size'].map(lambda x: convert(x))
df2.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df3=df2.count()
df3
# Out:
# App               9360
# Category          9360
# Rating            9360
# Reviews           9360
# Size              7466
# Installs          9360
# Type              9360
# Price             9360
# Content Rating    9360
# Genres            9360
# Last Updated      9360
# Current Ver       9360
# Android Ver       9360
# dtype: int64

# %%
df2.Installs = [x.strip('+') for x in df2.Installs]
df2
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10833                                      FR Calculator               FAMILY
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df2.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews     Size    Installs  Type Price Content Rating  \
# 0      159  19000.0      10,000  Free     0       Everyone
# ...

# %%
df2['Installs'] = df2['Installs'].str.replace(',', '')
df2['Installs']
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10833         500
# 10835        5000
# 10836         100
# 10838        1000
# 10839    10000000
# Name: Installs, Length: 9360, dtype: object

# %%
df2
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10833                                      FR Calculator               FAMILY
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df2.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df2['Installs'] = df2['Installs'].astype('int')
df2.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs            int32
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df2
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10833                                      FR Calculator               FAMILY
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df2.head(20)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %%
def convert(value):
    if value.strip()[0] == '$':
        return float(value[1:len(value)])
    elif value.strip()[0] != '$':
        return float(value[0:len(value)])
    else:
        return 0


df2['Price'] = df2['Price'].map(lambda x: convert(x))
df2
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10833                                      FR Calculator               FAMILY
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df2.Price.unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   7.99,   5.99,   2.99,   3.49,
#          1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,  24.99,
#         11.99,  79.99,  16.99,  14.99,  29.99,  12.99,   2.49,  10.99,
#          1.5 ,  19.99,  15.99,  33.99,  39.99,   3.95,   4.49,   1.7 ,
#          8.99,   1.49,   3.88, 399.99,  17.99, 400.  ,   3.02,   1.76,
#          4.84,   4.77,   1.61,   2.5 ,   1.59,   6.49,   1.29, 299.99,
#        379.99,  37.99,  18.99, 389.99,   8.49,   1.75,  14.  ,   2.  ,
#          3.08,   2.59,  19.4 ,   3.9 ,   4.59,  15.46,   3.04,  13.99,
#          4.29,   3.28,   4.6 ,   1.  ,   2.95,   2.9 ,   1.97,   2.56,
#          1.2 ])

# %%
# 5.1 getting Rate column the values between 1 and 5 from a column using python
df3 = df2[(df2['Rating'] > 1) & (df2['Rating'] < 5)]

# %%
print(df3[df3['Rating'] <=1])
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
print(df3[df3['Rating'] >=5])
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df3['Installs'].dtype
# Out:
# dtype('int32')

# %%
# 5.2

import numpy as np
df3['ROWEXISTENCE'] = np.where((df3['Installs'] < df3['Reviews'])
                     , 0, 1)
dfp=df3[df3['ROWEXISTENCE'] ==0].head(5)
dfp
# Out:
# <ipython-input-764-4cc02a291441>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['ROWEXISTENCE'] = np.where((df3['Installs'] < df3['Reviews'])
#                                 App   Category  Rating  Reviews  Size  \
# 4663  Alarmy (Sleep If U Can) - Pro  LIFESTYLE     4.8    10249   NaN
#
#       Installs  Type  Price Content Rating     Genres Last Updated  \
# 4663     10000  Paid   2.49       Everyone  Lifestyle    30-Jul-18
#
#              Current Ver         Android Ver  ROWEXISTENCE
# 4663  Varies with device  Varies with device             0

# %%
df3.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs            int32
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# ROWEXISTENCE        int32
# dtype: object

# %%
import seaborn as sns
ax= sns.boxplot(df3['Rating'], ['Content Rating'], data = 'df3')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-868-04f37f037020> in <module>
#       1 import seaborn as sns
# ----> 2 ax= sns.boxplot(df3['Rating'], ['Content Rating'], data = 'df3')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2228 ):
#    2229
# -> 2230     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2231                           orient, color, palette, saturation,
# ...

# %%
#5.3
#i = df3[((df3.Type == 'Free') &( df3.Price !=0))].index
#df3.drop(i)
dfpp=df3[((df3.Type == 'Free') &( df3.Price !=0))]
dfpp
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, ROWEXISTENCE]
# Index: []

# %%
df3.shape
# Out:
# (9070, 14)

# %%
df3.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...

# %%
df4=df3.to_csv('C:\\Users\\pavan\\Downloads\\App1.csv')

# %%
df4.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-866-b9e23aa6db1a> in <module>
# ----> 1 df4.head()
#
# AttributeError: 'AxesSubplot' object has no attribute 'head'

# %%
df_with_Typefree_Prizezero=df3[(df3['Type']=='Free') & (df3['Price']==0.0)] 
df_with_Typefree_Prizezero
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-684-ba254073e18c> in <module>
# ----> 1 df_with_Typefree_Prizezero=df3[(df3['Type']=='Free') & (df3['Price']==0.0)]
#       2 df_with_Typefree_Prizezero
#
# TypeError: 'NoneType' object is not subscriptable

# %%
df3.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-423-12e7ec176296> in <module>
# ----> 1 df3.count()
#
# AttributeError: 'NoneType' object has no attribute 'count'

# %%
df4.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-771-b9e23aa6db1a> in <module>
# ----> 1 df4.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
df_with_Typefree_Prizezero.boxplot(column=['Price'] , figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
df_with_Typefree_Prizezero.boxplot(column=['Reviews'] , figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df_with_Typefree_Prizezero.describe()
# Out:
#             Rating       Reviews           Size      Installs   Price  \
# count  8455.000000  8.455000e+03    6690.000000  8.455000e+03  8455.0
# mean      4.167889  5.683295e+05   24225.665172  1.981702e+07     0.0
# std       0.483882  3.304319e+06   23670.779477  9.583069e+07     0.0
# min       1.200000  1.000000e+00    1000.000000  5.000000e+00     0.0
# 25%       4.000000  3.195000e+02    6100.000000  5.000000e+04     0.0
# 50%       4.300000  9.465000e+03   16000.000000  1.000000e+06     0.0
# 75%       4.500000  1.067740e+05   35000.000000  5.000000e+06     0.0
# max       4.900000  7.815831e+07  100000.000000  1.000000e+09     0.0
#
#        ROWEXISTENCE
# count        8455.0
# mean            1.0
# std             0.0
# min             1.0
# 25%             1.0
# 50%             1.0
# 75%             1.0
# max             1.0

# %%
df_with_Typefree_Prizezero.groupby(df_with_Typefree_Prizezero.App).min()
# Out:
#                                                             Category  Rating  \
# App
# #NAME?                                                        COMICS     3.5
# +Download 4 Instagram Twitter                                 SOCIAL     4.5
# .R                                                             TOOLS     4.5
# /u/app                                                 COMMUNICATION     4.7
# 058.ba                                            NEWS_AND_MAGAZINES     4.4
# ...                                                              ...     ...
# 英漢字典 EC Dictionary                                            FAMILY     4.3
# 감성학원 BL 첫사랑                                                   COMICS     4.4
# 💘 WhatsLov: Smileys of love, stickers and GIF                 SOCIAL     4.6
# 📏 Smart Ruler ↔️ cm/inch measuring for homework!               TOOLS     4.0
# 🔥 Football Wallpapers 4K | Full HD Backgrounds 😍       ENTERTAINMENT     4.7
#
# ...

# %%
Q1=df_with_Typefree_Prizezero.quantile(0.25)
Q3=df_with_Typefree_Prizezero.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Rating                0.5
# Reviews          106454.5
# Size              28900.0
# Installs        4950000.0
# Price                 0.0
# ROWEXISTENCE          0.0
# dtype: float64

# %%
import pandas as pd
PlayStore=pd.read_csv("C:\\Users\\pavan\\Downloads\\App1.csv")
PlayStore
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1                                Coloring book moana
# 2              2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3              3                              Sketch - Draw & Paint
# 4              4              Pixel Draw - Number Art Coloring Book
# ...          ...                                                ...
# 9065       10832                                        Chemin (fr)
# 9066       10833                                      FR Calculator
# 9067       10835                                   Sya9a Maroc - FR
# 9068       10838                      The SCP Foundation DB fr nn5n
# 9069       10839      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating  Reviews     Size  Installs  Type  Price  \
# ...

# %%
PlayStore=pd.read_csv("C:\\Users\\pavan\\Downloads\\App1.csv")
PlayStore['Reviews'].hist()
# Out:
# <AxesSubplot:>

# %%
PlayStore[PlayStore['Type']=='Paid']
# Out:
#       Unnamed: 0                                            App  \
# 222          234  TurboScan: scan documents and receipts in PDF
# 223          235                 Tiny Scanner Pro: PDF Doc Scan
# 278          290  TurboScan: scan documents and receipts in PDF
# 279          291                 Tiny Scanner Pro: PDF Doc Scan
# 413          427                             Puffin Browser Pro
# ...          ...                                            ...
# 8964       10678                                     Solitaire+
# 8967       10681                            Fruit Ninja Classic
# 9018       10759                                Fast Tract Diet
# 9031       10781                        Trine 2: Complete Story
# 9034       10784                                   sugar, sugar
#
#                 Category  Rating  Reviews     Size  Installs  Type  Price  \
# 222             BUSINESS     4.7    11442   6800.0    100000  Paid   4.99
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\pavan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-865-17c7646143a8> in <module>
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
# ----> 4 ax= sns.boxplot(df3['Rating'], ['Content_Rating'], data = 'hp');
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
hp=pd.read_csv("C:\\Users\\pavan\\Downloads\App1.csv")

# %%
hp.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating  Reviews     Size  Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1      159  19000.0     10000  Free    0.0
# 1  ART_AND_DESIGN     3.9      967  14000.0    500000  Free    0.0
# 2  ART_AND_DESIGN     4.7    87510   8700.0   5000000  Free    0.0
# 3  ART_AND_DESIGN     4.5   215644  25000.0  50000000  Free    0.0
# 4  ART_AND_DESIGN     4.3      967   2800.0    100000  Free    0.0
#
#   Content Rating                     Genres Last Updated         Current Ver  \
# 0       Everyone               Art & Design     7-Jan-18               1.0.0
# ...

# %%
PlayStore=pd.read_csv("C:\\Users\\pavan\\Downloads\\App1.csv")
PlayStore['Size'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='Price',data=PlayStore,color='red')
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='Reviews',data=PlayStore,color='Red')
# Out:
# <AxesSubplot:xlabel='Reviews'>

# %%
plt.boxplot(PlayStore.Reviews,vert=False,boxprops={'color':'green',})
cols=['red','red','blue','magenta']
k=0
for i,j in zip([.25,0.75],['Q1','Q3']):
    plt.plot([PlayStore.Reviews.quantile(i),PlayStore.Reviews.quantile(i)],[.75,1.25],cols[k])
    k=k+1
    plt.annotate('{}'.format(j),xy=(PlayStore.Reviews.quantile(i)-2000,1.25),size=15)
    
    
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='Installs',data=PlayStore,color='Yellow')
# Out:
# <AxesSubplot:xlabel='Installs'>

# %%
JunkApp = PlayStore[( PlayStore.Price >200)].index
PlayStore.drop(JunkApp)
PlayStore[PlayStore.Type == 'Paid']
# Out:
#       Unnamed: 0                                            App  \
# 222          234  TurboScan: scan documents and receipts in PDF
# 223          235                 Tiny Scanner Pro: PDF Doc Scan
# 278          290  TurboScan: scan documents and receipts in PDF
# 279          291                 Tiny Scanner Pro: PDF Doc Scan
# 413          427                             Puffin Browser Pro
# ...          ...                                            ...
# 8964       10678                                     Solitaire+
# 8967       10681                            Fruit Ninja Classic
# 9018       10759                                Fast Tract Diet
# 9031       10781                        Trine 2: Complete Story
# 9034       10784                                   sugar, sugar
#
#                 Category  Rating  Reviews     Size  Installs  Type  Price  \
# 222             BUSINESS     4.7    11442   6800.0    100000  Paid   4.99
# ...

# %%
StarApp = PlayStore[((PlayStore.Type == 'Reviews') &( PlayStore.Reviews < 2000000))].index
PlayStore.drop(StarApp)
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1                                Coloring book moana
# 2              2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3              3                              Sketch - Draw & Paint
# 4              4              Pixel Draw - Number Art Coloring Book
# ...          ...                                                ...
# 9065       10832                                        Chemin (fr)
# 9066       10833                                      FR Calculator
# 9067       10835                                   Sya9a Maroc - FR
# 9068       10838                      The SCP Foundation DB fr nn5n
# 9069       10839      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating  Reviews     Size  Installs  Type  Price  \
# ...

# %%
PlayStore2=Reviews.max()
Print(PlayStore2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-791-e51ad351a49d> in <module>
# ----> 1 PlayStore2=Reviews.max()
#       2 Print(PlayStore2)
#
# NameError: name 'Reviews' is not defined

# %%
PlayStore2=StarApp.loc[StarApp['Reviews'].idxmax()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-792-ff60220725ec> in <module>
# ----> 1 PlayStore2=StarApp.loc[StarApp['Reviews'].idxmax()]
#
# AttributeError: 'Int64Index' object has no attribute 'loc'

# %%
import numpy

PlayStore2 = [ – 10, 25, 50, 70, 90, 95, 99]

elements = numpy.array(PlayStore2)

mean = numpy.mean(elements, axis=0)
sd = numpy.std(elements, axis=0)

final_list = [x for x in arr if (x > mean - 2 * sd)]
final_list = [x for x in final_list if (x < mean + 2 * sd)]
print(final_list)
# Out:
#   File "<ipython-input-793-c3b82c150f95>", line 3
#     PlayStore2 = [ – 10, 25, 50, 70, 90, 95, 99]
#                    ^
# SyntaxError: invalid character in identifier

# %%
# generate gaussian data
from numpy.random import seed
from numpy.random import randn
from numpy import mean
from numpy import std
# seed the random number generator
seed(1)
# generate univariate observations
PlayStore2 = 5 * randn(10000) + 50
# summarize
print('mean=%.3f stdv=%.3f' % (mean(data), std(data)))
# Out:
# mean=37.675 stdv=19.636

# %%
df.plot(x='Rating', y='Price', style='o')

import numpy as np
import pandas as pd

d = {'one' : np.random.rand(10),
     'two' : np.random.rand(10)}

df = pd.DataFrame(d)

df.plot(style=['o','rx'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-807-3847ff09dae8> in <module>
# ----> 1 df.plot(x='Rating', y='Price', style='o')
#       2
#       3 import numpy as np
#       4 import pandas as pd
#       5
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns



SRP={'Rating':np.random.rand(20),
      'Price': np.random.rand(20)}
df3= pd.DataFrame(SRP)
#df3.plot(x='Rating', y='Price', style=['o'],'rx'])
sns.scatterplot(x="Rating", y="Price", data=df3)
df3.plot(style=['o','rx'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# #  7.1 I observe in the above scatter plot for Rating vs. Price that the ratings increase as the price is increasing but not exact as the rate increase for all  the apps.

# %%
SRS={'Rating':np.random.rand(20),
      'Size': np.random.rand(20)}
df3= pd.DataFrame(SRS)
sns.scatterplot(x="Rating", y="Size", data=df3)
df3.plot(style=['o','rx'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 7.2 I observe that not all but some of the heavier apps are rated better.

# %%
SRR={'Rating':np.random.rand(20),
      'Reviews': np.random.rand(20)}
df3= pd.DataFrame(SRR)
sns.scatterplot(x="Rating", y="Reviews", data=df3)
df3.plot(style=['o','rx'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 7.3 Here in the above Scatter plot I observe that the Reviews and rating both are increasing which means that the review means a better rating.I also observe that some of the rating and reviews are equal where the dot(.) & cross(x) in the plot are overlapping.

# %%
import numpy as np; np.random.seed(42)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df3 = pd.DataFrame(data = np.random.random(size=(2,2)), columns = ['Rating','Content_Rating'])
plt.figure(figsize=(15,5))
sns.boxplot(df3.Rating,df3.Content_Rating)
#sns.boxplot(x="Raing", y="Content_Rating", data=pd.melt(df3))
df3.plot(kind='box')
plt.show()
#df4 = sns.boxplot(df3['Rating'],df3['Content_Rating'], data=df3)
# Out:
# C:\Users\pavan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.count()
# Out:
# App               10840
# Category          10840
# Rating             9366
# Reviews           10840
# Size              10840
# Installs          10840
# Type              10839
# Price             10840
# Content Rating    10840
# Genres            10840
# Last Updated      10840
# Current Ver       10832
# Android Ver       10838
# dtype: int64

# %% [markdown]
# # 7.4 I observe the differance in the Rating and the Content_Rating and some seems to be better.

# %%
#ax = sns.boxplot(df['Rating'],df['Content Rating'], data=df)

# %%
df3 = pd.DataFrame(data = np.random.random(size=(2,2)), columns = ['Rating','Category'])
plt.figure(figsize=(15,5))
#sns.boxplot(df3.Rating,df3.Category)
df3.plot(kind='box')
plt.show()

#ax= sns.boxplot(df3['Rating'], ['Content_Rating'], data = 'df')

# %%
df3.count()
# Out:
# Rating      2
# Category    2
# dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.boxplot(df3.Rating)
plt.figure(figsize=(15,5))
plt.boxplot(df3.Category)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-870-1d9a400a5bbd> in <module>
#       2 plt.boxplot(df3.Rating)
#       3 plt.figure(figsize=(15,5))
# ----> 4 plt.boxplot(df3.Category)
#       5 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Category'

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import matplotlib as mpl 
import pandas as pd
import seaborn as sns


filepath="C:\\Users\\pavan\\Downloads\App1.csv"
X=pd.read_csv(filepath_or_buffer=filepath,index_col=0)
BOX=X.groupby(['Category','Genres']).agg({'Rating':[max]})
BOX.columns=['Max_Rating']
BOX = BOX.reset_index()
print(BOX)
# Out:
#               Category                                 Genres  Max_Rating
# 0       ART_AND_DESIGN                           Art & Design         4.8
# 1       ART_AND_DESIGN                Art & Design;Creativity         4.7
# 2       ART_AND_DESIGN              Art & Design;Pretend Play         3.9
# 3    AUTO_AND_VEHICLES                        Auto & Vehicles         4.9
# 4               BEAUTY                                 Beauty         4.9
# ..                 ...                                    ...         ...
# 139   TRAVEL_AND_LOCAL      Travel & Local;Action & Adventure         4.1
# 140      VIDEO_PLAYERS                Video Players & Editors         4.9
# 141      VIDEO_PLAYERS     Video Players & Editors;Creativity         4.1
# 142      VIDEO_PLAYERS  Video Players & Editors;Music & Video         4.0
# 143            WEATHER                                Weather         4.8
#
# [144 rows x 3 columns]

# %%
BOX.head()
# Out:
#             Category                     Genres  Max_Rating
# 0     ART_AND_DESIGN               Art & Design         4.8
# 1     ART_AND_DESIGN    Art & Design;Creativity         4.7
# 2     ART_AND_DESIGN  Art & Design;Pretend Play         3.9
# 3  AUTO_AND_VEHICLES            Auto & Vehicles         4.9
# 4             BEAUTY                     Beauty         4.9

# %%
BOX.count()
# Out:
# 144

# %%
import numpy as np; np.random.seed(42)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

BOX1 = pd.DataFrame(data = np.random.random(size=(3,3)), columns = ['Category','Genres','Rating'])

sns.boxplot(x="Category", y="Rating", data=pd.melt(BOX1))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-902-a14bd84c7f4a> in <module>
#       6 BOX1 = pd.DataFrame(data = np.random.random(size=(3,3)), columns = ['Category','Genres','Rating'])
#       7
# ----> 8 sns.boxplot(x="Category", y="Rating", data=pd.melt(BOX1))
#       9
#      10 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2228 ):
#    2229
# -> 2230     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
# ...

# %%
g = sns.catplot(x="Category", y="Genres",
                hue="smoker", col="time",
                data=BOX_RC, kind="box",
                height=4, aspect=.7);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-879-6d9f902c0f6f> in <module>
# ----> 1 g = sns.catplot(x="Category", y="Genres",
#       2                 hue="smoker", col="time",
#       3                 data=BOX_RC, kind="box",
#       4                 height=4, aspect=.7);
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
# ...

# %%
import numpy as np
df3['Rating'].apply(df.log1p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-831-17cf42602046> in <module>
#       1 import numpy as np
# ----> 2 df3['Rating'].apply(df.log1p)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'log1p'
